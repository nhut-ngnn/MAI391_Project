# %% [markdown]
# <a href="https://colab.research.google.com/github/nhut-ngnn/MAI391_Project/blob/main/House_price_visualize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/MAI391_ComputerProject/train.csv")

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.countplot(x=df['MSSubClass'], ax=ax[0])
sns.countplot(x=df['MSZoning'], ax=ax[1])
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20,10))
sns.boxplot(x=df['LotFrontage'], ax=ax[0, 0])
df['LotFrontage'].hist(bins=50, ax=ax[0, 1])

sns.boxplot(x=df['LotArea'], ax=ax[1, 0])
df['LotArea'].hist(bins=100, ax=ax[1, 1])
ax.shape
# Out:
# (2, 2)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
sns.countplot(x=df['Street'], ax=ax[0])
sns.countplot(x=df['Alley'], ax=ax[1])
# Out:
# <Axes: xlabel='Alley', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(15,16))
sns.countplot(x=df['LotShape'], ax=ax[0, 0])
sns.countplot(x=df['LandContour'], ax=ax[0, 1])
sns.countplot(x=df['Utilities'], ax=ax[1, 0])
sns.countplot(x=df['LotConfig'], ax=ax[1, 1])
sns.countplot(x=df['LandSlope'], ax=ax[2, 0])
# sns.countplot(x=df['Neighborhood'], ax=ax[2, 1])
sns.countplot(x=df['Condition1'], ax=ax[3, 0])
sns.countplot(x=df['Condition2'], ax=ax[3, 1])
sns.countplot(x=df['BldgType'], ax=ax[4, 0])
sns.countplot(x=df['HouseStyle'], ax=ax[4, 1])
# Out:
# <Axes: xlabel='HouseStyle', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
sns.boxplot(x=df['OverallQual'], ax=ax[0])
sns.boxplot(x=df['OverallCond'], ax=ax[1])
# Out:
# <Axes: xlabel='OverallCond'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
sns.histplot(x=df['YearBuilt'],bins=50 ,ax=ax[0])
sns.histplot(x=df['YearRemodAdd'],bins=50 ,ax=ax[1])
# Out:
# <Axes: xlabel='YearRemodAdd', ylabel='Count'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.countplot(x=df['RoofStyle'], ax=ax[0])
sns.countplot(x=df['RoofMatl'], ax=ax[1])
# Out:
# <Axes: xlabel='RoofMatl', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(30,10))
sns.countplot(x=df['Exterior1st'], ax=ax[0])
sns.countplot(x=df['Exterior2nd'], ax=ax[1])
# Out:
# <Axes: xlabel='Exterior2nd', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
sns.countplot(x=df['MasVnrType'], ax=ax[0])
sns.histplot(x=df['MasVnrArea'],bins=10 ,ax=ax[1])
# df['MasVnrArea'].hist(bins=10, ax=ax[1])
# sns.boxplot(x=df['MasVnrArea'], ax=ax[1])
# Out:
# <Axes: xlabel='MasVnrArea', ylabel='Count'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(10,5))
sns.countplot(x=df['ExterQual'], ax=ax[0, 0])
sns.countplot(x=df['ExterCond'], ax=ax[0, 1])

sns.countplot(x=df['Foundation'], ax=ax[1, 0])
sns.countplot(x=df['BsmtQual'], ax=ax[1, 1])
sns.countplot(x=df['BsmtCond'], ax=ax[2, 0])
sns.countplot(x=df['BsmtExposure'], ax=ax[2, 1])
# Out:
# <Axes: xlabel='BsmtExposure', ylabel='count'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(15,10))
sns.countplot(x=df['BsmtFinType1'], ax=ax[0, 0])
sns.histplot(x=df['BsmtFinSF1'], ax=ax[0, 1])

sns.countplot(x=df['BsmtFinType2'], ax=ax[1, 0])
sns.histplot(x=df['BsmtFinSF2'], ax=ax[1, 1])

sns.histplot(x=df['BsmtUnfSF'], ax=ax[2, 0])
sns.histplot(x=df['BsmtUnfSF'], ax=ax[2, 1])
# Out:
# <Axes: xlabel='BsmtUnfSF', ylabel='Count'>

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(15,10))
sns.countplot(x=df['Heating'], ax=ax[0,0])
sns.countplot(x=df['HeatingQC'], ax=ax[0,1])
sns.countplot(x=df['CentralAir'], ax=ax[1,0])
sns.countplot(x=df['Electrical'], ax=ax[1,1])

sns.histplot(x=df['1stFlrSF'],bins=30, ax=ax[2,0])
sns.histplot(x=df['2ndFlrSF'],bins=30, ax=ax[2,1])
# Out:
# <Axes: xlabel='2ndFlrSF', ylabel='Count'>

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
sns.boxplot(x=df['SalePrice'], ax=ax[0])
sns.histplot(x=df['SalePrice'],bins=30, ax=ax[1])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>
